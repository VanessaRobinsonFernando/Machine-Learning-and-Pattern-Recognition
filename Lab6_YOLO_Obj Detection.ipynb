# %%
'''YOLO (You Only Look Once) is one of the most widely used object detection algorithms
today. This exercise will explore its usage with a webcam to enable real-time object
detection.'''

# %%
#Set up the environment. OpenCV and YOLO need to be installed.
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\anaconda3\lib\site-packages (from opencv-python) (1.26.4)

# %%
#We install the ultralytics library that makes working with YOLO very easy and hassle-free.
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.19-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.7 kB 640.0 kB/s eta 0:00:01
#      ------------------- ------------------ 20.5/40.7 kB 640.0 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/40.7 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------- 40.7/40.7 kB 177.1 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (2.3.0)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.18.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.10.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\user\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\user\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.19-py3-none-any.whl (757 kB)
#    ---------------------------------------- 0.0/757.9 kB ? eta -:--:--
#    --- ------------------------------------ 61.4/757.9 kB 1.7 MB/s eta 0:00:01
#    ------ --------------------------------- 122.9/757.9 kB 1.2 MB/s eta 0:00:01
#    ------- -------------------------------- 143.4/757.9 kB 1.2 MB/s eta 0:00:01
#    ------------- -------------------------- 256.0/757.9 kB 1.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 307.2/757.9 kB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 368.6/757.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 542.7/757.9 kB 1.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 563.2/757.9 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 655.4/757.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  757.8/757.9 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 757.9/757.9 kB 1.5 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading torchvision-0.18.0-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.1/1.2 MB 3.6 MB/s eta 0:00:01
#    ------ --------------------------------- 0.2/1.2 MB 2.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.3/1.2 MB 2.3 MB/s eta 0:00:01
#    ------------- -------------------------- 0.4/1.2 MB 2.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.2 MB 2.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.5/1.2 MB 2.1 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.2 MB 2.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.2 MB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 0.7/1.2 MB 1.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.8/1.2 MB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.0/1.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 2.1 MB/s eta 0:00:00
# Installing collected packages: torchvision, thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 torchvision-0.18.0 ultralytics-8.2.19

# %%
'''The YOLO model is loaded using the ultralytics library and specifies the location of the YOLO weights file in the yolo-Weights/yolov8n.pt.'''
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck",
"boat","traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
"dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack",
"umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite",
"baseball bat","baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wineglass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange",
"broccoli", "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa",
"pottedplant", "bed", "diningtable", "toilet", "tvmonitor", "laptop", "mouse",
"remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink",
"refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier",
"toothbrush"]

# %%
import cv2
import math
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
# Out:
# True

# %%
'''The while loop starts and it reads each frame from the webcam using cap.read(). Then it passes the frame to the YOLO model for object detection. The results of object detection are
stored in the ‘results’ variable'''

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    success, img = cap.read()
    
    # Check if frame is read correctly
    if not success:
        print("Failed to capture image")
        continue
    
    results = model(img, stream=True)
    
    for r in results:
        boxes = r.boxes
        
        for box in boxes:
            # Bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)
            
            # Confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->", confidence)
            
            # Class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])
            
            # Object details
            org = (x1, y1)
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)
        
    cv2.imshow('Webcam', img)
    
    if cv2.waitKey(1) == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 3 persons, 1 chair, 482.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.34
# Class name --> person
# Speed: 24.5ms preprocess, 482.7ms inference, 2921.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 292.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 13.1ms preprocess, 292.3ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 254.2ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 5.7ms preprocess, 254.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 wine glass, 1 chair, 242.8ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.29
# Class name --> wineglass
# Speed: 0.0ms preprocess, 242.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 dining table, 292.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 4.3ms preprocess, 292.5ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 wine glass, 1 chair, 1 dining table, 227.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.64
# Class name --> chair
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.39
# Class name --> wineglass
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 3.8ms preprocess, 227.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 wine glass, 1 chair, 1 dining table, 267.0ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.3
# Class name --> wineglass
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 6.0ms preprocess, 267.0ms inference, 11.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 wine glass, 1 chair, 246.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.69
# Class name --> chair
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.47
# Class name --> wineglass
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.0ms preprocess, 246.7ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 253.6ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 4.9ms preprocess, 253.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 253.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 8.3ms preprocess, 253.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 252.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.3
# Class name --> chair
# Speed: 4.0ms preprocess, 252.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 230.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.0ms preprocess, 230.8ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 263.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.0ms preprocess, 263.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 256.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.64
# Class name --> chair
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.37
# Class name --> chair
# Speed: 2.7ms preprocess, 256.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 256.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.69
# Class name --> chair
# Confidence ---> 0.58
# Class name --> person
# Speed: 10.7ms preprocess, 256.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 274.4ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Speed: 4.5ms preprocess, 274.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 314.9ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.43
# Class name --> chair
# Speed: 6.8ms preprocess, 314.9ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 277.1ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.42
# Class name --> chair
# Speed: 6.8ms preprocess, 277.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 270.7ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 15.0ms preprocess, 270.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 256.1ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Speed: 5.4ms preprocess, 256.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 chair, 243.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.73
# Class name --> chair
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 6.2ms preprocess, 243.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 dining table, 228.3ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.7
# Class name --> chair
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.26
# Class name --> diningtable
# Speed: 2.0ms preprocess, 228.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 246.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.74
# Class name --> chair
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Speed: 5.6ms preprocess, 246.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 241.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.6
# Class name --> person
# Speed: 4.6ms preprocess, 241.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 242.9ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 3.7ms preprocess, 242.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bowl, 1 chair, 253.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.3
# Class name --> bowl
# Speed: 2.8ms preprocess, 253.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 dining table, 1 laptop, 328.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.52
# Class name --> cup
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.32
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> diningtable
# Speed: 5.2ms preprocess, 328.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 dining table, 2 laptops, 253.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.28
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> diningtable
# Speed: 5.8ms preprocess, 253.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 chair, 2 laptops, 243.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.72
# Class name --> cup
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> chair
# Speed: 5.1ms preprocess, 243.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 dining table, 3 laptops, 227.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 5.5ms preprocess, 227.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 dining table, 1 laptop, 256.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> cup
# Confidence ---> 0.33
# Class name --> chair
# Confidence ---> 0.29
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 256.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 dining table, 1 laptop, 236.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.29
# Class name --> diningtable
# Speed: 7.2ms preprocess, 236.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 228.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> cup
# Speed: 5.2ms preprocess, 228.9ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 1 book, 248.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.34
# Class name --> book
# Speed: 4.5ms preprocess, 248.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 2 chairs, 2 laptops, 1 book, 259.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> cup
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
# Speed: 3.8ms preprocess, 259.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 230.6ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> cup
# Confidence ---> 0.47
# Class name --> person
# Speed: 4.3ms preprocess, 230.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 chair, 2 laptops, 1 book, 240.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> chair
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 5.4ms preprocess, 240.1ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 laptop, 228.0ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 4.2ms preprocess, 228.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 256.8ms
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Speed: 4.2ms preprocess, 256.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 345.4ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 3.1ms preprocess, 345.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 chair, 1 laptop, 247.5ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.41
# Class name --> cup
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 2.9ms preprocess, 247.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 chair, 2 laptops, 252.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> cup
# Confidence ---> 0.29
# Class name --> chair
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 4.7ms preprocess, 252.0ms inference, 11.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 dining table, 1 laptop, 246.2ms
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 2.9ms preprocess, 246.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 dining table, 1 laptop, 251.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.65
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.35
# Class name --> cup
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 3.3ms preprocess, 251.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 laptop, 231.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> cup
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 4.1ms preprocess, 231.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dining table, 1 laptop, 236.5ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.41
# Class name --> diningtable
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 4.1ms preprocess, 236.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 258.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 3.0ms preprocess, 258.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dining table, 1 laptop, 285.1ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 4.3ms preprocess, 285.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 2 laptops, 293.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 5.0ms preprocess, 293.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 tv, 1 laptop, 393.4ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.3
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> chair
# Speed: 4.2ms preprocess, 393.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 3 laptops, 1 sink, 1 book, 300.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> sink
# Confidence ---> 0.32
# Class name --> chair
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.5ms preprocess, 300.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 1 book, 287.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> book
# Speed: 2.2ms preprocess, 287.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 294.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Speed: 5.0ms preprocess, 294.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 remote, 1 keyboard, 346.4ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.31
# Class name --> keyboard
# Confidence ---> 0.31
# Class name --> remote
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 5.8ms preprocess, 346.4ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 book, 287.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 5.4ms preprocess, 287.4ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 282.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.37
# Class name --> cup
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 0.0ms preprocess, 282.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 tv, 1 laptop, 300.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.44
# Class name --> cup
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.36
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 2.0ms preprocess, 300.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 tv, 1 laptop, 403.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Confidence ---> 0.34
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 5.6ms preprocess, 403.0ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 tv, 1 laptop, 259.1ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Confidence ---> 0.36
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 4.9ms preprocess, 259.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 tv, 1 laptop, 245.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> cup
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 245.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 2 laptops, 1 book, 260.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.38
# Class name --> cup
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 4.3ms preprocess, 260.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 laptop, 223.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.42
# Class name --> cup
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> person
# Speed: 3.2ms preprocess, 223.2ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 dining table, 247.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Confidence ---> 0.32
# Class name --> diningtable
# Confidence ---> 0.3
# Class name --> chair
# Speed: 4.3ms preprocess, 247.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 2 laptops, 242.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> chair
# Speed: 4.0ms preprocess, 242.0ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 laptop, 243.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> chair
# Speed: 4.4ms preprocess, 243.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 1 laptop, 384.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.46
# Class name --> cup
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.43
# Class name --> laptop
# Speed: 2.9ms preprocess, 384.3ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 2 laptops, 244.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> cup
# Speed: 3.7ms preprocess, 244.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 4 laptops, 246.0ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 5.5ms preprocess, 246.0ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 2 laptops, 244.2ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.5
# Class name --> laptop
# Speed: 6.4ms preprocess, 244.2ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 3 laptops, 249.5ms
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.59
# Class name --> chair
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> chair
# Speed: 4.7ms preprocess, 249.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 2 laptops, 251.8ms
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.63
# Class name --> chair
# Confidence ---> 0.48
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 4.9ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 3 laptops, 238.0ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.31
# Class name --> chair
# Speed: 5.3ms preprocess, 238.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 342.7ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.51
# Class name --> laptop
# Speed: 2.8ms preprocess, 342.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bowl, 2 laptops, 249.7ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> bowl
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> person
# Speed: 4.1ms preprocess, 249.7ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 2 cell phones, 242.2ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Confidence ---> 0.36
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 5.0ms preprocess, 242.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 1 cell phone, 239.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.77
# Class name --> cell phone
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.38
# Class name --> person
# Speed: 4.3ms preprocess, 239.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 2 remotes, 232.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.62
# Class name --> remote
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> remote
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 7.2ms preprocess, 232.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 228.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> cell phone
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.9ms preprocess, 228.9ms inference, 11.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 remote, 343.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.51
# Class name --> remote
# Confidence ---> 0.42
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 5.3ms preprocess, 343.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 232.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.77
# Class name --> cell phone
# Confidence ---> 0.76
# Class name --> person
# Speed: 5.0ms preprocess, 232.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 cell phone, 232.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.6
# Class name --> cell phone
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.32
# Class name --> laptop
# Speed: 3.7ms preprocess, 232.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 2 remotes, 1 cell phone, 250.5ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.74
# Class name --> cell phone
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.47
# Class name --> remote
# Confidence ---> 0.34
# Class name --> remote
# Speed: 6.3ms preprocess, 250.5ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tv, 1 laptop, 1 remote, 3 cell phones, 252.3ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.7
# Class name --> cell phone
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> remote
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.5
# Class name --> tvmonitor
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.4
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 1.9ms preprocess, 252.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 1 remote, 3 cell phones, 245.5ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.62
# Class name --> cell phone
# Confidence ---> 0.61
# Class name --> cell phone
# Confidence ---> 0.61
# Class name --> remote
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 3.2ms preprocess, 245.5ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 1 cell phone, 344.7ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.76
# Class name --> cell phone
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 4.0ms preprocess, 344.7ms inference, 17.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 chairs, 2 laptops, 1 cell phone, 253.3ms
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 1.7ms preprocess, 253.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 4 laptops, 1 cell phone, 249.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.8
# Class name --> chair
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 4.6ms preprocess, 249.4ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 3 laptops, 1 cell phone, 260.2ms
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 3.3ms preprocess, 260.2ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 tv, 2 laptops, 269.8ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.45
# Class name --> tvmonitor
# Speed: 3.9ms preprocess, 269.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 1 tv, 3 laptops, 373.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.65
# Class name --> tvmonitor
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> chair
# Speed: 4.1ms preprocess, 373.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 tv, 4 laptops, 254.6ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> chair
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.57
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 3.0ms preprocess, 254.6ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 tv, 3 laptops, 255.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> tvmonitor
# Speed: 5.4ms preprocess, 255.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 tv, 3 laptops, 254.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.64
# Class name --> chair
# Confidence ---> 0.59
# Class name --> chair
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> tvmonitor
# Speed: 5.2ms preprocess, 254.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 tv, 3 laptops, 265.8ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.46
# Class name --> tvmonitor
# Speed: 3.5ms preprocess, 265.8ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 1 tv, 4 laptops, 391.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.62
# Class name --> chair
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.39
# Class name --> tvmonitor
# Speed: 4.4ms preprocess, 391.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 1 dining table, 1 tv, 5 laptops, 268.3ms
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.72
# Class name --> chair
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.26
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 5.6ms preprocess, 268.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 3 laptops, 264.7ms
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.73
# Class name --> chair
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.31
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.0ms preprocess, 264.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 2 laptops, 264.2ms
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.78
# Class name --> chair
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 264.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 3 laptops, 241.2ms
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> chair
# Confidence ---> 0.57
# Class name --> chair
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 3.2ms preprocess, 241.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 3 laptops, 363.2ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> chair
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.43
# Class name --> chair
# Speed: 5.8ms preprocess, 363.2ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 4 laptops, 281.9ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.32
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> chair
# Speed: 5.5ms preprocess, 281.9ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cake, 2 chairs, 3 laptops, 308.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> cake
# Confidence ---> 0.39
# Class name --> chair
# Speed: 5.3ms preprocess, 308.2ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cake, 3 chairs, 3 laptops, 326.5ms
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.31
# Class name --> cake
# Speed: 5.5ms preprocess, 326.5ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 3 laptops, 429.6ms
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> chair
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.27
# Class name --> chair
# Speed: 3.3ms preprocess, 429.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 3 laptops, 291.2ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.76
# Class name --> chair
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.49
# Class name --> laptop
# Speed: 5.6ms preprocess, 291.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 3 laptops, 331.4ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> chair
# Speed: 6.1ms preprocess, 331.4ms inference, 11.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 304.2ms
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> person
# Speed: 3.7ms preprocess, 304.2ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 5 laptops, 432.6ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 5.6ms preprocess, 432.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 4 laptops, 297.8ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.66
# Class name --> chair
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 6.9ms preprocess, 297.8ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 chair, 4 laptops, 337.1ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.76
# Class name --> chair
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.26
# Class name --> cup
# Speed: 3.1ms preprocess, 337.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 5 laptops, 321.3ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 4.4ms preprocess, 321.3ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 5 laptops, 376.0ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.62
# Class name --> chair
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.5ms preprocess, 376.0ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 3 laptops, 272.7ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> chair
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.0ms preprocess, 272.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 3 laptops, 266.4ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> chair
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 2.6ms preprocess, 266.4ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 2 laptops, 252.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> chair
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 5.3ms preprocess, 252.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 321.8ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> chair
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Speed: 6.9ms preprocess, 321.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 4 laptops, 278.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> chair
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 3.0ms preprocess, 278.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 5 laptops, 265.9ms
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.65
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> laptop
# ...
#
# 0: 480x640 2 persons, 4 chairs, 1 dining table, 1 tv, 2 laptops, 369.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.72
# Class name --> chair
# Confidence ---> 0.72
# Class name --> tvmonitor
# Confidence ---> 0.62
# Class name --> chair
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> diningtable
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.32
# Class name --> chair
# Speed: 71.8ms preprocess, 369.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 1 dining table, 1 tv, 1 laptop, 380.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.81
# Class name --> tvmonitor
# Confidence ---> 0.77
# Class name --> chair
# Confidence ---> 0.63
# Class name --> chair
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.37
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> chair
# Speed: 6.3ms preprocess, 380.4ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 1 dining table, 1 tv, 1 laptop, 279.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.78
# Class name --> chair
# Confidence ---> 0.71
# Class name --> tvmonitor
# Confidence ---> 0.67
# Class name --> chair
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.4
# Class name --> diningtable
# Speed: 3.6ms preprocess, 279.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 1 dining table, 1 tv, 264.3ms
# Confidence ---> 0.77
# Class name --> chair
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.74
# Class name --> chair
# Confidence ---> 0.74
# Class name --> tvmonitor
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.4
# Class name --> diningtable
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.8ms preprocess, 264.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 1 dining table, 1 tv, 490.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.77
# Class name --> chair
# Confidence ---> 0.69
# Class name --> tvmonitor
# Confidence ---> 0.64
# Class name --> chair
# Confidence ---> 0.56
# Class name --> chair
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.38
# Class name --> diningtable
# Speed: 5.0ms preprocess, 490.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 1 dining table, 1 tv, 260.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.82
# Class name --> tvmonitor
# Confidence ---> 0.71
# Class name --> chair
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.31
# Class name --> diningtable
# Speed: 5.2ms preprocess, 260.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 chairs, 1 dining table, 1 tv, 400.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> tvmonitor
# Confidence ---> 0.77
# Class name --> chair
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 3.0ms preprocess, 400.8ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 1 tv, 1 laptop, 263.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.75
# Class name --> tvmonitor
# Confidence ---> 0.66
# Class name --> chair
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.32
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> chair
# Speed: 2.1ms preprocess, 263.6ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 tv, 2 laptops, 367.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> tvmonitor
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 2.0ms preprocess, 367.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 chairs, 1 tv, 1 laptop, 1 book, 315.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> tvmonitor
# Confidence ---> 0.65
# Class name --> chair
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 4.6ms preprocess, 315.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 5 chairs, 1 tv, 2 laptops, 1 book, 380.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> chair
# Confidence ---> 0.67
# Class name --> tvmonitor
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> chair
# Confidence ---> 0.27
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 4.8ms preprocess, 380.1ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 chairs, 1 tv, 1 laptop, 1 book, 283.4ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> chair
# Speed: 9.0ms preprocess, 283.4ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 chair, 1 tv, 2 laptops, 390.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.62
# Class name --> tvmonitor
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 0.0ms preprocess, 390.9ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 2 chairs, 1 tv, 2 laptops, 271.5ms
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.7
# Class name --> chair
# Confidence ---> 0.6
# Class name --> tvmonitor
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 2.0ms preprocess, 271.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 2 chairs, 1 tv, 2 laptops, 433.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 5.7ms preprocess, 433.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 2 chairs, 2 tvs, 3 laptops, 1 book, 278.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> tvmonitor
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.51
# Class name --> book
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 4.8ms preprocess, 278.0ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 6 chairs, 1 dining table, 1 tv, 1 laptop, 382.4ms
# Confidence ---> 0.77
# Class name --> tvmonitor
# Confidence ---> 0.77
# Class name --> chair
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> diningtable
# Confidence ---> 0.27
# Class name --> chair
# Speed: 5.2ms preprocess, 382.4ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 5 chairs, 1 tv, 1 laptop, 1 book, 261.1ms
# Confidence ---> 0.76
# Class name --> chair
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.69
# Class name --> tvmonitor
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> person
# Speed: 7.1ms preprocess, 261.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 6 chairs, 1 tv, 1 laptop, 381.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.78
# Class name --> chair
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.63
# Class name --> tvmonitor
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> chair
# Speed: 3.8ms preprocess, 381.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 5 chairs, 1 dining table, 2 tvs, 1 laptop, 1 book, 276.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.72
# Class name --> chair
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> chair
# Confidence ---> 0.65
# Class name --> tvmonitor
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.29
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> diningtable
# Confidence ---> 0.28
# Class name --> book
# Speed: 24.9ms preprocess, 276.6ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 6 chairs, 1 dining table, 2 tvs, 1 laptop, 587.8ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.79
# Class name --> tvmonitor
# Confidence ---> 0.75
# Class name --> chair
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.32
# Class name --> diningtable
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 15.5ms preprocess, 587.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 7 chairs, 1 dining table, 2 tvs, 2 laptops, 319.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.74
# Class name --> chair
# Confidence ---> 0.62
# Class name --> tvmonitor
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.32
# Class name --> diningtable
# Confidence ---> 0.31
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> chair
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 4.3ms preprocess, 319.2ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 6 chairs, 1 dining table, 1 tv, 2 laptops, 445.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.76
# Class name --> tvmonitor
# Confidence ---> 0.74
# Class name --> chair
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> chair
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 3.1ms preprocess, 445.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 5 chairs, 1 dining table, 1 tv, 294.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.76
# Class name --> chair
# Confidence ---> 0.64
# Class name --> tvmonitor
# Confidence ---> 0.59
# Class name --> chair
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> chair
# Speed: 3.6ms preprocess, 294.6ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 5 chairs, 1 dining table, 1 tv, 1 laptop, 1 sink, 469.2ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.66
# Class name --> tvmonitor
# Confidence ---> 0.64
# Class name --> chair
# Confidence ---> 0.57
# Class name --> chair
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.43
# Class name --> sink
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> diningtable
# Confidence ---> 0.28
# Class name --> chair
# Confidence ---> 0.27
# Class name --> chair
# Speed: 5.1ms preprocess, 469.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 1 dining table, 1 tv, 1 laptop, 303.1ms
# Confidence ---> 0.83
# Class name --> tvmonitor
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.69
# Class name --> chair
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> diningtable
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.0ms preprocess, 303.1ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 1 dining table, 1 tv, 1 laptop, 1 cell phone, 573.4ms
# Confidence ---> 0.76
# Class name --> tvmonitor
# Confidence ---> 0.73
# Class name --> chair
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.52
# Class name --> diningtable
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.31
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> chair
# Speed: 2.1ms preprocess, 573.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
